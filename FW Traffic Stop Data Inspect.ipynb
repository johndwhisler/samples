# %%
import pandas as pd
in_fw = pd.read_csv('in_fort_wayne_2020_04_01.csv')
in_fw.head()
# Out:
#    raw_row_number        date      time  \
# 0               1  2007-09-01  00:00:00
# 1               2  2007-09-01  00:01:00
# 2               3  2007-09-01  00:09:00
# 3               4  2007-09-01  00:12:00
# 4               5  2007-09-01  00:13:00
#
#                                 location        lat        lng       type  \
# 0     1100 ST JOE RIVER DR & PARNELL AVE  41.108560 -85.125549  vehicular
# 1                  2800 ST JOE CENTER RD  41.133496 -85.106281  vehicular
# 2          699 CONGRESS AVE & HANNA ST S  41.043906 -85.127456  vehicular
# 3  6299 ST JOE CENTER RD & MAPLECREST RD  41.134916 -85.062233  vehicular
# 4                         6400 ST JOE RD  41.140301 -85.093136  vehicular
#
#        disposition arrest_made citation_issued warning_issued   outcome
# 0         INACTIVE       False           False          False       NaN
# 1  WRITTEN WARNING       False           False           True   warning
# ...

# %%
in_fw.isnull().sum()
# Out:
# raw_row_number         0
# date                   0
# time                   0
# location              41
# lat                 7972
# lng                 7972
# type                   0
# disposition         1574
# arrest_made         1574
# citation_issued     1574
# warning_issued      1574
# outcome            89200
# dtype: int64

# %%
in_fw.shape
# Out:
# (265019, 12)

# %%
in_fw['type'].value_counts()
# Out:
# vehicular    265019
# Name: type, dtype: int64
