# %%
import random

def play():
  user = input("'r' for rock, 'p' for paper, 's' for scissors \n  ")
  computer = random.choice(['r', 'p', 's'])

  if user == computer:
    return f'It\'s a tie.  The computer had {computer}'
  if is_win(user, computer):
    return f'You won! The computer had {computer}'
  return f'You lost! The computer had {computer}'

# r>s, s>p, p>r

def is_win(player, opponent):
  if (player == 'r' and opponent == 's') or (player == 's' and opponent == 'p')\
      or (player == 'p' and opponent == 'r'):
      return True
  #if (player == 'r' and oppenent == 'p') or (player == 's' and opponent == 'r')\
  #    or (player == 'p' and opponent == 's')
  #   return False
play()
# Out:
# 'r' for rock, 'p' for paper, 's' for scissors
#   r
# 'You lost! The computer had p'
